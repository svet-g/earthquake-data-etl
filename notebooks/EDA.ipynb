# %% [markdown]
# # Exploratory Data Analysis - Last 30 Days of Earthquakes

# %%
import geopandas

path_to_file = '../data/raw/earthquake-data-last-30-days.geojson'

df = geopandas.read_file(path_to_file)

df[df['gap'].isna()]
# Out:
#                  id  mag                                      place  \
# 39     ak025aitzed2  1.9  64 km ESE of Denali National Park, Alaska
# 40     ak025aitxtgp  3.4                14 km SW of Susitna, Alaska
# 41     ak025aitudx3  1.3                85 km S of McCarthy, Alaska
# 45     ak025aitn71x  1.5   42 km SE of Denali National Park, Alaska
# 47     ak025aitdpbf  1.4              38 km WNW of Cantwell, Alaska
# ...             ...  ...                                        ...
# 11358  ak02595ckur2  2.1              85 km S of Sand Point, Alaska
# 11365  ak02595chay3  2.3              90 km S of Sand Point, Alaska
# 11367  ak02595ch7no  2.2            95 km SSE of Sand Point, Alaska
# 11368  ak02595cgtj2  2.0            88 km SSE of Sand Point, Alaska
# 11369  ak02595cglzp  2.0           108 km SSE of Sand Point, Alaska
#
#                 time        updated    tz  \
# 39     1755413869660  1755414001621  None
# 40     1755413413013  1755431532368  None
# 41     1755412451115  1755412537631  None
# 45     1755410456215  1755410684747  None
# 47     1755410187319  1755410347121  None
# ...              ...            ...   ...
# 11358  1752850195149  1755139111389  None
# 11365  1752849227077  1755139110953  None
# 11367  1752849183727  1755139137640  None
# 11368  1752849080623  1755139137866  None
# 11369  1752849022939  1755139137179  None
#
#                                                      url  \
# 39     https://earthquake.usgs.gov/earthquakes/eventp...
# 40     https://earthquake.usgs.gov/earthquakes/eventp...
# 41     https://earthquake.usgs.gov/earthquakes/eventp...
# 45     https://earthquake.usgs.gov/earthquakes/eventp...
# 47     https://earthquake.usgs.gov/earthquakes/eventp...
# ...                                                  ...
# 11358  https://earthquake.usgs.gov/earthquakes/eventp...
# 11365  https://earthquake.usgs.gov/earthquakes/eventp...
# 11367  https://earthquake.usgs.gov/earthquakes/eventp...
# 11368  https://earthquake.usgs.gov/earthquakes/eventp...
# 11369  https://earthquake.usgs.gov/earthquakes/eventp...
#
#                                                   detail   felt  cdi  ...  \
# 39     https://earthquake.usgs.gov/earthquakes/feed/v...    NaN  NaN  ...
# 40     https://earthquake.usgs.gov/earthquakes/feed/v...  183.0  3.1  ...
# 41     https://earthquake.usgs.gov/earthquakes/feed/v...    NaN  NaN  ...
# 45     https://earthquake.usgs.gov/earthquakes/feed/v...    NaN  NaN  ...
# 47     https://earthquake.usgs.gov/earthquakes/feed/v...    NaN  NaN  ...
# ...                                                  ...    ...  ...  ...
# 11358  https://earthquake.usgs.gov/earthquakes/feed/v...    NaN  NaN  ...
# 11365  https://earthquake.usgs.gov/earthquakes/feed/v...    NaN  NaN  ...
# 11367  https://earthquake.usgs.gov/earthquakes/feed/v...    NaN  NaN  ...
# 11368  https://earthquake.usgs.gov/earthquakes/feed/v...    NaN  NaN  ...
# 11369  https://earthquake.usgs.gov/earthquakes/feed/v...    NaN  NaN  ...
#
#        sources                              types nst  dmin   rms gap magType  \
# 39        ,ak,                ,origin,phase-data, NaN   NaN  0.18 NaN      ml
# 40     ,ak,us,  ,dyfi,origin,phase-data,shakemap, NaN   NaN  0.80 NaN      ml
# 41        ,ak,                ,origin,phase-data, NaN   NaN  0.37 NaN      ml
# 45        ,ak,                ,origin,phase-data, NaN   NaN  0.73 NaN      ml
# 47        ,ak,                ,origin,phase-data, NaN   NaN  0.34 NaN      ml
# ...        ...                                ...  ..   ...   ...  ..     ...
# 11358     ,ak,                ,origin,phase-data, NaN   NaN  0.93 NaN      ml
# 11365     ,ak,                ,origin,phase-data, NaN   NaN  0.65 NaN      ml
# 11367     ,ak,                ,origin,phase-data, NaN   NaN  0.71 NaN      ml
# 11368     ,ak,                ,origin,phase-data, NaN   NaN  0.68 NaN      ml
# 11369     ,ak,                ,origin,phase-data, NaN   NaN  0.68 NaN      ml
#
#              type                                              title  \
# 39     earthquake  M 1.9 - 64 km ESE of Denali National Park, Alaska
# 40     earthquake                M 3.4 - 14 km SW of Susitna, Alaska
# 41     earthquake                M 1.3 - 85 km S of McCarthy, Alaska
# 45     earthquake   M 1.5 - 42 km SE of Denali National Park, Alaska
# 47     earthquake              M 1.4 - 38 km WNW of Cantwell, Alaska
# ...           ...                                                ...
# 11358  earthquake              M 2.1 - 85 km S of Sand Point, Alaska
# 11365  earthquake              M 2.3 - 90 km S of Sand Point, Alaska
# 11367  earthquake            M 2.2 - 95 km SSE of Sand Point, Alaska
# 11368  earthquake            M 2.0 - 88 km SSE of Sand Point, Alaska
# 11369  earthquake           M 2.0 - 108 km SSE of Sand Point, Alaska
#
#                                 geometry
# 39     POINT Z (-150.6263 63.2296 125.3)
# 40          POINT Z (-150.6836 61.44 45)
# 41      POINT Z (-142.9457 60.6675 22.6)
# 45        POINT Z (-151.092 63.2876 8.3)
# 47     POINT Z (-149.7055 63.4703 105.3)
# ...                                  ...
# 11358    POINT Z (-160.414 54.5663 16.5)
# 11365   POINT Z (-160.3289 54.5334 15.2)
# 11367   POINT Z (-159.9388 54.5419 16.9)
# 11368   POINT Z (-160.0283 54.5882 13.2)
# 11369    POINT Z (-159.9082 54.422 20.9)
#
# [1829 rows x 28 columns]

# %%
df.describe()
# Out:
#                 mag          time       updated          felt         cdi  \
# count  11370.000000  1.137000e+04  1.137000e+04    596.000000  596.000000
# mean       1.792173  1.754011e+12  1.754337e+12     57.228188    2.663423
# std        1.537428  7.291265e+08  7.091245e+08    592.286132    1.456370
# min       -1.320000  1.752849e+12  1.752854e+12      0.000000    0.000000
# 25%        0.770000  1.753385e+12  1.753807e+12      1.000000    2.000000
# 50%        1.385000  1.753946e+12  1.754410e+12      1.000000    2.200000
# 75%        2.250000  1.754635e+12  1.754996e+12      5.000000    3.400000
# max        8.800000  1.755440e+12  1.755441e+12  11124.000000    9.100000
#
#               mmi       tsunami           sig          nst         dmin  \
# count  257.000000  11370.000000  11370.000000  9542.000000  9540.000000
# mean     3.317751      0.001319     86.332454    29.288095     0.577551
# std      1.509595      0.036299    127.999303    28.791279     1.664053
# min      0.000000      0.000000      0.000000     0.000000     0.000000
# 25%      2.324000      0.000000      9.000000    12.000000     0.019595
# 50%      3.535000      0.000000     30.000000    20.000000     0.065820
# 75%      3.950000      0.000000     78.000000    36.000000     0.276475
# max      8.961000      1.000000   2089.000000   338.000000    47.502000
#
#                 rms          gap
# count  11369.000000  9541.000000
# mean       0.331405   108.552213
# std        0.321929    59.287459
# min        0.000000    11.000000
# 25%        0.100000    66.000000
# 50%        0.190000    92.000000
# 75%        0.530000   137.000000
# max        3.190000   359.000000

# %%
# check NAs
df.isna().sum()
# Out:
# id              0
# mag             0
# place           0
# time            0
# updated         0
# tz          11370
# url             0
# detail          0
# felt        10774
# cdi         10774
# mmi         11113
# alert       11213
# status          0
# tsunami         0
# sig             0
# net             0
# code            0
# ids             0
# sources         0
# types           0
# nst          1828
# dmin         1830
# rms             1
# gap          1829
# magType         0
# type            0
# title           0
# geometry        0
# dtype: int64

# %%
# can drop quite a few columns: tz, dmin, net, ids, code, title, type (see below!), rms, nst, types, sources, status, mmi, 

# KEEP:

# alert - green, yellow, orange, red - the nulls are no info coming from PAGER earthquake impact scale
# cdi - max reported intensity of the event
# depth - how deep the earthquake originates from but loads of error around calculation and placeholder values get put in like 33km as a default depth
# depthError - uncertainty of reported depths of the event in km
# detail - Link to GeoJSON detail feed from a GeoJSON summary feed
# felt - the total number of felt reports submitted to DYFI? system
# magType - already buckets earthquakes by magnitude
# sig - significance of the event calculated based on a number of factors, including: magnitude, maximum MMI, felt reports, and estimated impact.
# tsunami - This flag is set to "1" for large events in oceanic regions and "0" otherwise. The existence or value of this flag does not indicate if a tsunami actually did or will exist. 
# If the flag value is "1", the event will include a link to the NOAA Tsunami website for tsunami information.

# GAP issue:

# gap - The largest azimuthal gap between azimuthally adjacent stations (in degrees). In general, the smaller this number, the more reliable is the calculated horizontal position of the earthquake.
# Earthquake locations in which the azimuthal gap exceeds 180 degrees typically have large location and depth uncertainties.

# anything with gap larger than 180 have large location and depth uncertainty - remove all rows without data or above 180 degrees

# DROP type if != 'earthquake'
# the drop type column

# %%
# remove anything that isn't type 'earthquake'
df = df[df['type'] == 'earthquake']

df['id'].count()
# Out:
# np.int64(11081)

# %%
[column for column in df.columns]
# Out:
# ['id',
#  'mag',
#  'place',
#  'time',
#  'updated',
#  'tz',
#  'url',
#  'detail',
#  'felt',
#  'cdi',
#  'mmi',
#  'alert',
#  'status',
#  'tsunami',
#  'sig',
#  'net',
#  'code',
#  'ids',
#  'sources',
#  'types',
#  'nst',
#  'dmin',
#  'rms',
#  'gap',
#  'magType',
#  'type',
#  'title',
#  'geometry']
